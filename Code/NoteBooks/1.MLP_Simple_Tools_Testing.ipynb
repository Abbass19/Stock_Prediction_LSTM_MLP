# %% [markdown]
# This NoteNook is Dedicated to Test the functions and classes of MLP. They were tested before and we functional. However I have made some changes. Which resulted in this, dessinging another Notebook just for that

# %%
import sys
import os

project_root = os.path.abspath('../../')  

if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from Code.engine.MLP import SimpleBaseLine
from Code.engine.preprocessing import dataloader, feature_1_denormalize
from Code.engine.mlp_trainer import train_model_loop, evaluate,run_optuna_search
import matplotlib.pyplot as plt
import numpy as np


batch_size  = 16
window_size = 16

model = SimpleBaseLine(hidden_size=64, input_feature= window_size)
train_data, test_data , scaler_1, scaler_2 = dataloader()



run_optuna_search()
# Out:
# Done Training epoch 0 out of 40 with error 1682.6450965553522
# Done Training epoch 1 out of 40 with error 15255.455767810345
# Done Training epoch 2 out of 40 with error 8865.765585757792
# Done Training epoch 3 out of 40 with error 6269.492218464613
# Done Training epoch 4 out of 40 with error 5030.358168166131
# Done Training epoch 5 out of 40 with error 4426.136832177639
# Done Training epoch 6 out of 40 with error 3696.000548094511
# Done Training epoch 7 out of 40 with error 3581.822422493249
# Done Training epoch 8 out of 40 with error 2963.3338530398905
# Done Training epoch 9 out of 40 with error 3556.0906672403216
# Done Training epoch 10 out of 40 with error 2617.2124272063375
# Done Training epoch 11 out of 40 with error 2279.1486518979073
# Done Training epoch 12 out of 40 with error 1967.775842037052
# Done Training epoch 13 out of 40 with error 1511.152306061238
# Done Training epoch 14 out of 40 with error 1344.6043683234602
# ...

# %%
plt.plot(feature_1_denormalize(data, scaler_1 =  scaler_1, scaler_2 = scaler_2))
plt.plot(all_prediction, label = 'Predicted Values')
plt.legend()
plt.show()

# %% [markdown]
# This Work here proves that these functions for MLP trainer and the MLP class work at least.
